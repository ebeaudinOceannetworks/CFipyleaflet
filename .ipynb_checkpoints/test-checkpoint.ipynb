# %%
# test

import main
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # test
# ----> 3 import main
#
# File ~/Desktop/CF/CFipyleaflet/main.py:9
#       6 from widgets import create_variable_selector, create_buttons, create_text_inputs
#       8 # 1. Load data
# ----> 9 station_data = StationData(ds_stations)
#      10 lat_center = float(station_data.lats.mean())
#      11 lon_center = float(station_data.lons.mean())
#
# NameError: name 'ds_stations' is not defined
