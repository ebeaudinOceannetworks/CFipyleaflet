# %%
import sys
import os

current_folder = os.path.dirname(os.path.abspath(''))
cf_root = os.path.abspath(os.path.join(current_folder, '..'))
sys.path.append(cf_root)

from CFipyleaflet import main
#main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 8
#       5 cf_root = os.path.abspath(os.path.join(current_folder, '..'))
#       6 sys.path.append(cf_root)
# ----> 8 from CFipyleaflet import main
#       9 #main()
#
# File ~/Desktop/CF/CFipyleaflet/main.py:6
#       4 import ipywidgets as widgets
#       5 from IPython.display import display
# ----> 6 from ipywidgets import HBox, VBox, Icon
#       8 from .cor_parser import parse_cor_folder, read_cor_data
#       9 from .data import StationMetadata, StationData
#
# ImportError: cannot import name 'Icon' from 'ipywidgets' (/Users/ebeaudin/miniconda3/lib/python3.13/site-packages/ipywidgets/__init__.py)
